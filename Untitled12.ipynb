# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense
from tensorflow.keras.models import Model
import numpy as np

# -----------------------------
# 1. Dataset
# -----------------------------
eng_sentences = ["How are you?", "What is your name?"]
tam_sentences = [" நீங்கள் எப்படி இருக்கிறீர்கள்? ",
                 " உங்கள் பெயர் என்ன? "]

# -----------------------------
# 2. Tokenize
# -----------------------------
eng_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
eng_tokenizer.fit_on_texts(eng_sentences)
eng_seq = eng_tokenizer.texts_to_sequences(eng_sentences)
eng_seq = tf.keras.preprocessing.sequence.pad_sequences(eng_seq, padding='post')

tam_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
tam_tokenizer.fit_on_texts(tam_sentences)
tam_seq = tam_tokenizer.texts_to_sequences(tam_sentences)
tam_seq = tf.keras.preprocessing.sequence.pad_sequences(tam_seq, padding='post')

# -----------------------------
# 3. Prepare Decoder Input & Target
# -----------------------------
decoder_input_seq = tam_seq[:, :-1]
decoder_target_seq = np.expand_dims(tam_seq[:, 1:], -1)

eng_vocab = len(eng_tokenizer.word_index) + 1
tam_vocab = len(tam_tokenizer.word_index) + 1

max_eng_len = eng_seq.shape[1]
max_tam_len = decoder_input_seq.shape[1]

latent_dim = 64

# -----------------------------
# 4. Encoder
# -----------------------------
encoder_inputs = Input(shape=(max_eng_len,))
enc_emb = Embedding(eng_vocab, latent_dim, mask_zero=True)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(enc_emb)
encoder_states = [state_h, state_c]

# -----------------------------
# 5. Decoder
# -----------------------------
decoder_inputs = Input(shape=(max_tam_len,))
dec_emb = Embedding(tam_vocab, latent_dim, mask_zero=True)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=encoder_states)
decoder_dense = Dense(tam_vocab, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# -----------------------------
# 6. Model
# ------------------------------
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')
model.summary()

# -----------------------------
# 7. Train
# -----------------------------
model.fit([eng_seq, decoder_input_seq], decoder_target_seq,
          batch_size=2,
          epochs=300,
          verbose=0)

# -----------------------------
# 8. Inference Models
# -----------------------------
# Encoder
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder
dec_state_input_h = Input(shape=(latent_dim,))
dec_state_input_c = Input(shape=(latent_dim,))
dec_states_inputs = [dec_state_input_h, dec_state_input_c]

dec_emb2 = Embedding(tam_vocab, latent_dim, mask_zero=True)(decoder_inputs)
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=dec_states_inputs)
decoder_outputs2 = decoder_dense(decoder_outputs2)
decoder_model = Model([decoder_inputs] + dec_states_inputs,
                      [decoder_outputs2, state_h2, state_c2])

# -----------------------------
# 9. Translate function
# -----------------------------
def translate(sentence):
    seq = eng_tokenizer.texts_to_sequences([sentence])
    seq = tf.keras.preprocessing.sequence.pad_sequences(seq, maxlen=max_eng_len, padding='post')
    states = encoder_model.predict(seq)

    target_seq = np.zeros((1,1))

    # The original code produced a KeyError because tam_tokenizer.word_index[''] does not exist.
    # In sequence-to-sequence models, it's common to use special tokens like <start> and <end>
    # to signal the beginning and end of a sequence.
    # Since this model was not explicitly trained with such tokens,
    # we'll use the padding token (index 0) as a pragmatic substitute for both the
    # initial 'start' signal for the decoder and as an 'end' signal for stopping generation.
    # A more robust and canonical solution would involve adding explicit <start> and <end>
    # tokens to the training data and retraining the model.

    start_or_padding_token_index = 0 # Index 0 is typically used for padding by pad_sequences.

    target_seq[0,0] = start_or_padding_token_index # Initialize with the 'start' token (padding token)
    output_sentence = ""

    # Create an inverse word index for easy lookup
    reverse_word_index = {v: k for k, v in tam_tokenizer.word_index.items()}

    for _ in range(max_tam_len):
        output_tokens, h, c = decoder_model.predict([target_seq] + states)
        sampled_token_index = np.argmax(output_tokens[0,-1,:])

        # Stop if the model predicts the 'end' token (which we are using as padding token 0)
        # or if the predicted index is not found in our vocabulary (e.g., 0 itself, or an unknown word)
        if sampled_token_index == start_or_padding_token_index:
            break

        word = reverse_word_index.get(sampled_token_index)

        if word is None: # If sampled_token_index is not a known word (e.g., it's 0 or an out-of-vocabulary token)
            break

        output_sentence += word + " "
        target_seq[0,0] = sampled_token_index # Feed the predicted word as the next input
        states = [h, c] # Update the decoder states
    return output_sentence.strip()

# -----------------------------
# 10. Test Translation
# -----------------------------
for s in eng_sentences:
    print("English:", s)
    print("Tamil (predicted):", translate(s))
    print()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 4)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_5       │ (None, 2)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_3         │ (None, 4, 64)     │        512 │ input_layer_4[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_3         │ (None, 4)         │          0 │ input_layer_4[0]… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_4         │ (None, 2, 64)     │        448 │ input_layer_5[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, 64),      │     33,024 │ embedding_3[0][0… │
# │                     │ (None, 64),       │            │ not_equal_3[0][0] │
# │                     │ (None, 64)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ [(None, 2, 64),   │     33,024 │ embedding_4[0][0… │
# │                     │ (None, 64),       │            │ lstm_2[0][1],     │
# │                     │ (None, 64)]       │            │ lstm_2[0][2]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 2, 7)      │        455 │ lstm_3[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 67,463 (263.53 KB)
#  Trainable params: 67,463 (263.53 KB)
#  Non-trainable params: 0 (0.00 B)
# English: How are you?
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Tamil (predicted): எப்படி இருக்கிறீர்கள்?
#
# English: What is your name?
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Tamil (predicted): பெயர் என்ன?
